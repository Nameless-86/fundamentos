# %% [markdown]
# # Crear dummies

# %%
dataframe['pred'].describe()
# Out:
# count    14371.000000
# mean     13330.370120
# std      11993.928733
# min     -25871.683887
# 25%       4354.573911
# 50%      13242.618711
# 75%      22215.331711
# max      44971.308778
# Name: pred, dtype: float64

# %% [markdown]
# # Predichos vs reales

# %%
ultimo = resultado_ajustado.predict(dataframe)

# %%
plt.scatter(dataframe.ingreso_total_lab, ultimo)

# %%
plt.figure(figsize=(40, 40))

for idx, col in enumerate(dataframe.columns, start=1):  
    plt.subplot(10, 5, idx)
    plt.scatter(data=dataframe, x=col, y='ingreso_total_lab', alpha=.3)
    plt.title(col)
